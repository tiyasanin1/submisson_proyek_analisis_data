# %% [markdown]
# # Proyek Analisis Data: [Input Nama Dataset]
# - **Nama:**
# - **Email:**
# - **ID Dicoding:** [Input Username]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Pertanyaan 1 ->
# - Pertanyaan 2

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
#customer dataset
customers_df=pd.read_csv('data/customers_dataset.csv')
geolocation_df=pd.read_csv('data/geolocation_dataset.csv')
order_items_df=pd.read_csv('data/order_items_dataset.csv')
order_payments_df=pd.read_csv('data/order_payments_dataset.csv')
order_reviews_df=pd.read_csv('data/order_reviews_dataset.csv')
orders_df=pd.read_csv('data/orders_dataset.csv')
products_category_df=pd.read_csv('data/product_category_name_translation.csv')
products_df=pd.read_csv('data/products_dataset.csv')
sellers_df=pd.read_csv('data/sellers_dataset.csv')

# %%
products_df = products_df.merge(products_category_df, on='product_category_name', how='left')

# %%
df=orders_df.merge(order_items_df, on='order_id', how='inner')
df=df.merge(order_payments_df, on='order_id', how='inner',validate='m:m')
df=df.merge(order_reviews_df, on='order_id', how='inner')
df=df.merge(products_df, on='product_id',how='inner' )
df=df.merge(customers_df, on='customer_id', how='inner')
df=df.merge(sellers_df, on='seller_id',how='inner')

# %%
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2018-07-26 14:31:00           2018-08-07 15:27:45
# 4          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date  order_item_id  \
# 0           2017-10-18 00:00:00              1
# 1           2017-10-18 00:00:00              1
# 2           2017-10-18 00:00:00              1
# 3           2018-08-13 00:00:00              1
# 4           2018-09-04 00:00:00              1
#
#                          product_id  ... product_height_cm product_width_cm  \
# 0  87285b34884572647811a353c7ac498a  ...               8.0             13.0
# 1  87285b34884572647811a353c7ac498a  ...               8.0             13.0
# 2  87285b34884572647811a353c7ac498a  ...               8.0             13.0
# 3  595fac2a385ac33a80bd5114aec74eb8  ...              13.0             19.0
# 4  aa4383b373c6aca5d8797843e5594415  ...              19.0             21.0
#
#    product_category_name_english                customer_unique_id  \
# 0                     housewares  7c396fd4830fd04220f754e42b4e5bff
# 1                     housewares  7c396fd4830fd04220f754e42b4e5bff
# 2                     housewares  7c396fd4830fd04220f754e42b4e5bff
# 3                      perfumery  af07308b275d755c9edb36a90c618231
# 4                           auto  3a653a41f6f9fc3d2a113cf8398680e8
#
#    customer_zip_code_prefix customer_city  customer_state  \
# 0                      3149     sao paulo              SP
# 1                      3149     sao paulo              SP
# 2                      3149     sao paulo              SP
# 3                     47813     barreiras              BA
# 4                     75265    vianopolis              GO
#
#    seller_zip_code_prefix     seller_city  seller_state
# 0                    9350            maua            SP
# 1                    9350            maua            SP
# 2                    9350            maua            SP
# 3                   31570  belo horizonte            SP
# 4                   14840         guariba            SP
#
# [5 rows x 40 columns]

# %% [markdown]
# info data:
# - order_id: ID unik dari pesanan
# - customer_id: ID unik dari pelanggan yang membuat pesanan.
# - order_status: Status pesanan (seperti delivered, shipped, canceled).
# - order_purchase_timestamp: Waktu pesanan dilakukan.
# - order_approved_at: Waktu persetujuan pesanan.
# - order_delivered_carrier_date: Tanggal pengiriman oleh kurir.
# - order_delivered_customer_date: Tanggal pengiriman ke pelanggan.
# - order_estimated_delivery_date: Tanggal estimasi pengiriman ke pelanggan.
# - order_id: ID unik dari pesanan.
# - order_item_id: ID unik dari item dalam pesanan.
# - product_id: ID unik dari produk.
# - seller_id: ID unik dari penjual.
# - shipping_limit_date: Batas waktu pengiriman oleh penjual.
# - price: Harga item.
# - freight_value: Biaya pengiriman.
# - product_id: ID unik dari produk.
# - product_category_name: Nama kategori produk dalam bahasa Portugis.
# - product_name_length: Panjang nama produk.
# - product_description_length: Panjang deskripsi produk.
# - product_photos_qty: Jumlah foto produk.
# - product_weight_g: Berat produk dalam gram.
# - product_length_cm, product_height_cm, product_width_cm: Dimensi produk dalam cm.
# - seller_id: ID unik dari penjual.
# - seller_zip_code_prefix: Kode pos penjual.
# - seller_city: Kota asal penjual.
# - seller_state: Negara bagian asal penjual.
# - customer_id: ID unik dari pelanggan.
# - customer_unique_id: ID unik untuk mengidentifikasi pelanggan secara individual.
# - customer_zip_code_prefix: Kode pos pelanggan.
# - customer_city: Kota asal pelanggan.
# - customer_state: Negara bagian asal pelanggan.
# - order_id: ID unik dari pesanan.
# - payment_sequential: Urutan pembayaran untuk pesanan (jika ada lebih dari satu metode).
# - payment_type: Jenis pembayaran (seperti credit_card, boleto).
# - payment_installments: Jumlah angsuran untuk pembayaran.
# - payment_value: Jumlah pembayaran.
# - review_id: ID unik dari ulasan.
# - order_id: ID unik dari pesanan.
# - review_score: Skor ulasan (1-5).
# - review_comment_title: Judul ulasan (jika ada).
# - review_comment_message: Pesan ulasan (jika ada).
# - review_creation_date: Tanggal ulasan dibuat.
# - review_answer_timestamp: Tanggal ulasan dijawab oleh penjual.

# %% [markdown]
# **Insight:**
# - Total 39 columns dan 117329 baris
# - data berhasil digabungkan

# %% [markdown]
# ### Assessing Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117329 entries, 0 to 117328
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       117329 non-null  object
#  1   customer_id                    117329 non-null  object
#  2   order_status                   117329 non-null  object
#  3   order_purchase_timestamp       117329 non-null  object
#  4   order_approved_at              117314 non-null  object
#  5   order_delivered_carrier_date   116094 non-null  object
#  6   order_delivered_customer_date  114858 non-null  object
#  7   order_estimated_delivery_date  117329 non-null  object
#  8   order_item_id                  117329 non-null  int64
#  9   product_id                     117329 non-null  object
#  10  seller_id                      117329 non-null  object
#  11  shipping_limit_date            117329 non-null  object
#  12  price                          117329 non-null  float64
#  13  freight_value                  117329 non-null  float64
#  14  payment_sequential             117329 non-null  int64
#  15  payment_type                   117329 non-null  object
#  16  payment_installments           117329 non-null  int64
#  17  payment_value                  117329 non-null  float64
#  18  review_id                      117329 non-null  object
#  19  review_score                   117329 non-null  int64
#  20  review_comment_title           13892 non-null   object
#  21  review_comment_message         49679 non-null   object
#  22  review_creation_date           117329 non-null  object
#  23  review_answer_timestamp        117329 non-null  object
#  24  product_category_name          115634 non-null  object
#  25  product_name_lenght            115634 non-null  float64
#  26  product_description_lenght     115634 non-null  float64
#  27  product_photos_qty             115634 non-null  float64
#  28  product_weight_g               117309 non-null  float64
#  29  product_length_cm              117309 non-null  float64
#  30  product_height_cm              117309 non-null  float64
#  31  product_width_cm               117309 non-null  float64
#  32  product_category_name_english  115609 non-null  object
#  33  customer_unique_id             117329 non-null  object
#  34  customer_zip_code_prefix       117329 non-null  int64
#  35  customer_city                  117329 non-null  object
#  36  customer_state                 117329 non-null  object
#  37  seller_zip_code_prefix         117329 non-null  int64
#  38  seller_city                    117329 non-null  object
#  39  seller_state                   117329 non-null  object
# dtypes: float64(10), int64(6), object(24)
# memory usage: 35.8+ MB

# %%
# cek missing value
df.isna().sum()
# Out:
# order_id                              0
# customer_id                           0
# order_status                          0
# order_purchase_timestamp              0
# order_approved_at                    15
# order_delivered_carrier_date       1235
# order_delivered_customer_date      2471
# order_estimated_delivery_date         0
# order_item_id                         0
# product_id                            0
# seller_id                             0
# shipping_limit_date                   0
# price                                 0
# freight_value                         0
# payment_sequential                    0
# payment_type                          0
# payment_installments                  0
# payment_value                         0
# review_id                             0
# review_score                          0
# review_comment_title             103437
# review_comment_message            67650
# review_creation_date                  0
# review_answer_timestamp               0
# product_category_name              1695
# product_name_lenght                1695
# product_description_lenght         1695
# product_photos_qty                 1695
# product_weight_g                     20
# product_length_cm                    20
# product_height_cm                    20
# product_width_cm                     20
# product_category_name_english      1720
# customer_unique_id                    0
# customer_zip_code_prefix              0
# customer_city                         0
# customer_state                        0
# seller_zip_code_prefix                0
# seller_city                           0
# seller_state                          0
# dtype: int64

# %%
# cek duplikat
print('Jumlah duplikat:', df.duplicated().sum())

#cek deskripsi data
df.describe()
# Out:
# Jumlah duplikat: 0
#        order_item_id          price  freight_value  payment_sequential  \
# count  117329.000000  117329.000000  117329.000000       117329.000000
# mean        1.194121     120.524349      20.027514            1.094452
# std         0.684225     182.944843      15.828077            0.731174
# min         1.000000       0.850000       0.000000            1.000000
# 25%         1.000000      39.900000      13.080000            1.000000
# 50%         1.000000      74.900000      16.280000            1.000000
# 75%         1.000000     134.900000      21.180000            1.000000
# max        21.000000    6735.000000     409.680000           29.000000
#
#        payment_installments  payment_value   review_score  \
# count         117329.000000  117329.000000  117329.000000
# mean               2.940151     172.062565       4.031467
# std                2.775370     265.388194       1.387927
# min                0.000000       0.000000       1.000000
# 25%                1.000000      60.750000       4.000000
# 50%                2.000000     108.100000       5.000000
# 75%                4.000000     189.060000       5.000000
# max               24.000000   13664.080000       5.000000
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count        115634.000000               115634.000000       115634.000000
# mean             48.768018                  785.802861            2.205528
# std              10.033831                  652.382965            1.717783
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  346.000000            1.000000
# 50%              52.000000                  600.000000            1.000000
# 75%              57.000000                  983.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count     117309.000000      117309.000000      117309.000000
# mean        2110.763062          30.254456          16.612476
# std         3785.128931          16.177519          13.452625
# min            0.000000           7.000000           2.000000
# 25%          300.000000          18.000000           8.000000
# 50%          700.000000          25.000000          13.000000
# 75%         1800.000000          38.000000          20.000000
# max        40425.000000         105.000000         105.000000
#
#        product_width_cm  customer_zip_code_prefix  seller_zip_code_prefix
# count     117309.000000             117329.000000           117329.000000
# mean          23.071452              35060.118112            24450.781955
# std           11.745875              29849.496175            27582.364358
# min            6.000000               1003.000000             1001.000000
# 25%           15.000000              11250.000000             6429.000000
# 50%           20.000000              24240.000000            13660.000000
# 75%           30.000000              58770.000000            28035.000000
# max          118.000000              99990.000000            99730.000000

# %%
# cek missing value order_approved_at
miss_row=df[df['order_approved_at'].isnull()&(df['order_status']=='delivered')]
print(miss_row[['order_id', 'order_status', 'order_purchase_timestamp', 
                        'order_approved_at', 'order_delivered_carrier_date', 
                        'order_delivered_customer_date']])
# 50%             2017-03-02 12:06:06
# 75%             2017-03-03 12:01:55
# max             2017-03-09 07:28:47
# Name: order_delivered_customer_date, dtype: object

# %% [markdown]
# **Insight:**
#
# Kesalahan type data:
# - order_purchase_timestamp (object -> datetime)
# - order_approved_at (object -> datetime)
# - order_delivered_carrier_date (object -> datetime)
# - order_delivered_customer_date (object -> datetime)
# - order_estimated_delivery_date (object -> datetime)
# - shipping_limit_date (object -> datetime)
# - review_creation_date (object -> datetime)
# - review_answer_timestamp (object -> datetime)
#
# Missing value pada:
# - order_approved_at -> 15
# - order_delivered_carrier_date -> 1235
# - order_delivered_customer_date -> 2471
# - review_comment_title -> 103437
# - review_comment_message -> 67650
# - product_category_name -> 1695
# - product_name_lenght -> 1695
# - product_description_lenght -> 1695
# - product_photos_qty -> 1695
# - product_weight_g -> 20
# - product_length_cm -> 20
# - product_height_cm -> 20
# - product_width_cm -> 20
# - product_category_name_english -> 1720

# %% [markdown]
# ### Cleaning Data

# %%
datetime_coloms=['order_purchase_timestamp','order_approved_at','order_delivered_carrier_date','order_delivered_customer_date',
    'order_estimated_delivery_date','shipping_limit_date','review_creation_date','review_answer_timestamp']
for column in datetime_coloms:
    df[column]=pd.to_datetime(df[column])

# %%
- review_comment_title -> 103437
- review_comment_message -> 67650


- order_approved_at -> 15
- order_delivered_carrier_date -> 1235
- order_delivered_customer_date -> 2471

- product_category_name -> 1695
- product_name_lenght -> 1695

- product_description_lenght -> 1695
- product_photos_qty -> 1695
- product_weight_g -> 20
- product_length_cm -> 20
- product_height_cm -> 20
- product_width_cm -> 20
- product_category_name_english -> 1720
# Out:
#   Cell In[10], line 1
#     - review_comment_title -> 103437
#                            ^
# SyntaxError: invalid syntax

# %%
print('products_category_df', 1695/117329)
# Out:
# products_category_df 0.014446556264862055

# %%
df['product_category_name'].unique()
# Out:
# array(['utilidades_domesticas', 'perfumaria', 'automotivo', 'pet_shop',
#        'papelaria', nan, 'moveis_decoracao', 'moveis_escritorio',
#        'ferramentas_jardim', 'informatica_acessorios', 'cama_mesa_banho',
#        'brinquedos', 'telefonia', 'beleza_saude', 'eletronicos', 'bebes',
#        'cool_stuff', 'relogios_presentes', 'climatizacao',
#        'esporte_lazer', 'livros_interesse_geral',
#        'construcao_ferramentas_construcao', 'eletroportateis',
#        'alimentos', 'malas_acessorios', 'fashion_underwear_e_moda_praia',
#        'artigos_de_natal', 'fashion_bolsas_e_acessorios',
#        'instrumentos_musicais', 'construcao_ferramentas_iluminacao',
#        'livros_tecnicos', 'construcao_ferramentas_jardim',
#        'eletrodomesticos', 'market_place', 'agro_industria_e_comercio',
#        'artigos_de_festas', 'casa_conforto', 'cds_dvds_musicais',
#        'industria_comercio_e_negocios', 'consoles_games', 'moveis_quarto',
#        'construcao_ferramentas_seguranca', 'telefonia_fixa', 'bebidas',
#        'moveis_cozinha_area_de_servico_jantar_e_jardim',
#        'fashion_calcados', 'casa_construcao', 'audio',
#        'eletrodomesticos_2', 'fashion_roupa_masculina', 'cine_foto',
#        'moveis_sala', 'artes', 'alimentos_bebidas',
#        'tablets_impressao_imagem', 'fashion_esporte',
# 116890                    2018-08-10              1
# 117067                    2018-06-20              1
# 117074                    2017-09-19              1
# 117080                    2018-01-09              1
#
#                               product_id  ... product_height_cm  \
# 8       a1804276d9941ac0733cfd409f5206eb  ...              35.0
# 128     71225f49be70df4297892f6a5fa62171  ...               2.0
# 219     9820e04e332fc450d6fd975befc1bc28  ...              40.0
# 272     3bc5164bc7f4be77002d6651da65c98c  ...              11.0
# 314     5a848e4ab52fd5445cdc07aab1c40e48  ...              12.0
# ...                                  ...  ...               ...
# 116874  b1d207586fca400a2370d50a9ba1da98  ...               4.0
# 116890  8d39a63db6a98e40571f486e0c711cf7  ...               7.0
# 117067  e9cbc0910ab050cbd92fbeb051c270ea  ...              15.0
# 117074  0c877471e35049402bca235e06cb8063  ...              20.0
# 117080  5a848e4ab52fd5445cdc07aab1c40e48  ...              12.0
#
#        product_width_cm  product_category_name_english  \
# 8                  15.0                            NaN
# 128                11.0                            NaN
# 219                30.0                            NaN
# 272                19.0                            NaN
# 314                15.0                            NaN
# ...                 ...                            ...
# 116874             11.0                            NaN
# 116890             11.0                            NaN
# 117067             28.0                            NaN
# 117074             30.0                            NaN
# 117080             15.0                            NaN
#
#                       customer_unique_id  customer_zip_code_prefix  \
# 8       36edbb3fb164b1f16485364b6fb04c73                     98900
# 128     34c58672601f2c6d29db7efd1f6bf958                     38650
# 219     5cbf29b2dcf212a6a5d864b887238c72                      4842
# 272     1268b060098ed3f22c2e7c34cc72a1a8                     38240
# 314     f5cb81f98962f7504bef1e75579b6dff                     13474
# ...                                  ...                       ...
# 116874  e883ca09ca9171b6a644ddb4a970ad27                     70673
# 116890  75fe53e03a8a9797acb680ce8710da8b                     27264
# 117067  82ffeb20040f58e6c008e4402fa6f992                      1228
# 117074  1d627d8a6e1e33ea8eeeb7a17d998660                     11045
# 117080  da59579685bd771fdd4f90fb50d28cd3                      7240
#
#                 customer_city  customer_state  seller_zip_code_prefix  \
# 8                  santa rosa              RS                    5455
# 128     bonfinopolis de minas              MG                   13483
# 219                 sao paulo              SP                   11075
# 272                 itapagipe              MG                   31255
# 314                 americana              SP                    7133
# ...                       ...             ...                     ...
# 116874               brasilia              DF                    6506
# 116890          volta redonda              RJ                    7133
# 117067              sao paulo              SP                    2407
# 117074                 santos              SP                    3471
# 117080              guarulhos              SP                    7133
#
#                 seller_city  seller_state
# 8                 sao paulo            SP
# 128                 limeira            SP
# 219                  santos            SP
# 272          belo horizonte            MG
# 314               guarulhos            SP
# ...                     ...           ...
# 116874  santana de parnaiba            SP
# 116890            guarulhos            SP
# 117067            sao paulo            SP
# 117074            sao paulo            SP
# 117080            guarulhos            SP
#
# [1695 rows x 40 columns]

# %%
df['review_comment_message'].fillna(value='no coment', inplace=True)
df['review_comment_title'].fillna(value='no coment', inplace=True)

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %% [markdown]
# ### Pertanyaan 2:

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1
# - Conclution pertanyaan 2
